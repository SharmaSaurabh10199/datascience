# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
## selecting specific column 
df['Actor']
# Out:
# 0         Shah Rukh Khan
# 1            Salman Khan
# 2             Aamir Khan
# 3          Ranbir Kapoor
# 4          Ranveer Singh
# 5     Ayushmann Khurrana
# 6          Rajkummar Rao
# 7         Hrithik Roshan
# 8           Akshay Kumar
# 9          Kartik Aaryan
# 10          Varun Dhawan
# 11         Vicky Kaushal
# Name: Actor, dtype: object

# %%
## selecting moe than one column
df[['Actor','Film']]
# Out:
#                  Actor                      Film
# 0       Shah Rukh Khan                   Pathaan
# 1          Salman Khan           Tiger Zinda Hai
# 2           Aamir Khan                    Dangal
# 3        Ranbir Kapoor                Brahmastra
# 4        Ranveer Singh                 Padmaavat
# 5   Ayushmann Khurrana                 Andhadhun
# 6        Rajkummar Rao                     Stree
# 7       Hrithik Roshan                       War
# 8         Akshay Kumar                Good Newwz
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2
# 10        Varun Dhawan     Badrinath Ki Dulhania
# 11       Vicky Kaushal  Uri: The Surgical Strike

# %%
# selecting label based 
df.loc[0]
# Out:
# Actor                   Shah Rukh Khan
# Film                           Pathaan
# Year                              2023
# Genre                           Action
# BoxOffice(INR Crore)              1050
# IMDb                               7.2
# Name: 0, dtype: object

# %%
# based on the index 
df.iloc[0]
# Out:
# Actor                   Shah Rukh Khan
# Film                           Pathaan
# Year                              2023
# Genre                           Action
# BoxOffice(INR Crore)              1050
# IMDb                               7.2
# Name: 0, dtype: object

# %%
# perticular cell 
df.loc[0,'Actor']
# Out:
# 'Shah Rukh Khan'

# %%
# via index 
df.iloc[0,0]
# Out:
# 'Shah Rukh Khan'

# %%
## slicing 
df.loc[0:2, ['Actor','Film']]
# Out:
#             Actor             Film
# 0  Shah Rukh Khan          Pathaan
# 1     Salman Khan  Tiger Zinda Hai
# 2      Aamir Khan           Dangal

# %%
## slicing via index
df.iloc[0:2, 0:2]
# Out:
#             Actor             Film
# 0  Shah Rukh Khan          Pathaan
# 1     Salman Khan  Tiger Zinda Hai

# %%
# at, iat: optimized fro the single element 
df.at[0,'Actor']
# Out:
# 'Shah Rukh Khan'

# %%
df.iat[0,0]
# Out:
# 'Shah Rukh Khan'

# %%
## filter with the condition :: its column name is case sensitive 
df[df['imdb']>6]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'imdb'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 2
#       1 ## filter with the condition
# ----> 2 df[df['imdb']>6]
#
# ...

# %%
df[df['IMDb']>6]
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# ...

# %%
## multiple conditions in df 
df[(df['IMDb']>6) & (df['Year']>2018)]
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 7   Hrithik Roshan                       War  2019  Action
# 8     Akshay Kumar                Good Newwz  2019  Comedy
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2

# %%
# or condition
df[(df['IMDb']>6) | (df['Year']>2018)]
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# ...

# %%
## query function with string 
df.query("IMDb >7 and Year >2020")
# Out:
#             Actor     Film  Year   Genre  BoxOffice(INR Crore)  IMDb
# 0  Shah Rukh Khan  Pathaan  2023  Action                  1050   7.2

# %%
df.query("Actor == 'Shah Rukh Khan'")
# Out:
#             Actor     Film  Year   Genre  BoxOffice(INR Crore)  IMDb
# 0  Shah Rukh Khan  Pathaan  2023  Action                  1050   7.2

# %%
# using fstrings in query 
col='Actor'
df.query(f'{col}=="Shah Rukh Khan"')
# Out:
#             Actor     Film  Year   Genre  BoxOffice(INR Crore)  IMDb
# 0  Shah Rukh Khan  Pathaan  2023  Action                  1050   7.2
