# %%
import pandas as pd

# %%
df= pd.read_csv("data.csv")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
## sorting the values based on a column 
df.sort_values("Year")
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
## descending 
df.sort_values("Year",ascending=False)
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 2           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
## sorting based on year and imdb 
df.sort_values(["Year",'IMDb'])
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
# reset the index of the sorted values :
df.reset_index()
# Out:
#     index               Actor                      Film  Year  \
# 0       0      Shah Rukh Khan                   Pathaan  2023
# 1       1         Salman Khan           Tiger Zinda Hai  2017
# 2       2          Aamir Khan                    Dangal  2016
# 3       3       Ranbir Kapoor                Brahmastra  2022
# 4       4       Ranveer Singh                 Padmaavat  2018
# 5       5  Ayushmann Khurrana                 Andhadhun  2018
# 6       6       Rajkummar Rao                     Stree  2018
# 7       7      Hrithik Roshan                       War  2019
# 8       8        Akshay Kumar                Good Newwz  2019
# 9       9       Kartik Aaryan         Bhool Bhulaiyaa 2  2022
# 10     10        Varun Dhawan     Badrinath Ki Dulhania  2017
# 11     11       Vicky Kaushal  Uri: The Surgical Strike  2019
#
#               Genre  BoxOffice(INR Crore)  IMDb
# 0            Action                  1050   7.2
# 1            Action                   565   6.0
# ...

# %%
df.reset_index(drop=True) # to remove the index column
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.reset_index(drop=True, inplace=True)  # resets the df inpl;ace

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
# sort on the basis of index 
df.sort_index()
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df['Rank']= df['IMDb'].rank(ascending=False)

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
# renaming columns
df.rename(columns={'Actor': 'BollyActor'}, inplace= True)

# %%
df
# Out:
#             BollyActor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
# rename index 
df.rename(index={0:'row1',1: 'row2'}, inplace= True)

# %%
df
# Out:
#               BollyActor                      Film  Year            Genre  \
# row1      Shah Rukh Khan                   Pathaan  2023           Action
# row2         Salman Khan           Tiger Zinda Hai  2017           Action
# 2             Aamir Khan                    Dangal  2016        Biography
# 3          Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4          Ranveer Singh                 Padmaavat  2018       Historical
# 5     Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6          Rajkummar Rao                     Stree  2018    Horror Comedy
# 7         Hrithik Roshan                       War  2019           Action
# 8           Akshay Kumar                Good Newwz  2019           Comedy
# 9          Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10          Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11         Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
# changing the column order 
df.columns
# Out:
# Index(['BollyActor', 'Film', 'Year', 'Genre', 'BoxOffice(INR Crore)', 'IMDb',
#        'Rank'],
#       dtype='object')

# %% [markdown]
# df.columns= ["Name","Age"]

# %%
df = df[["BollyActor", "Film", "Year"]]   # Reorder as desired

# %%
df
# Out:
#               BollyActor                      Film  Year
# row1      Shah Rukh Khan                   Pathaan  2023
# row2         Salman Khan           Tiger Zinda Hai  2017
# 2             Aamir Khan                    Dangal  2016
# 3          Ranbir Kapoor                Brahmastra  2022
# 4          Ranveer Singh                 Padmaavat  2018
# 5     Ayushmann Khurrana                 Andhadhun  2018
# 6          Rajkummar Rao                     Stree  2018
# 7         Hrithik Roshan                       War  2019
# 8           Akshay Kumar                Good Newwz  2019
# 9          Kartik Aaryan         Bhool Bhulaiyaa 2  2022
# 10          Varun Dhawan     Badrinath Ki Dulhania  2017
# 11         Vicky Kaushal  Uri: The Surgical Strike  2019

# %%
## reording programatically 
cols=['Film'] +[col for col in df.columns if col!='Film']
df= df[cols]

# %%
df
# Out:
#                           Film          BollyActor  Year
# row1                   Pathaan      Shah Rukh Khan  2023
# row2           Tiger Zinda Hai         Salman Khan  2017
# 2                       Dangal          Aamir Khan  2016
# 3                   Brahmastra       Ranbir Kapoor  2022
# 4                    Padmaavat       Ranveer Singh  2018
# 5                    Andhadhun  Ayushmann Khurrana  2018
# 6                        Stree       Rajkummar Rao  2018
# 7                          War      Hrithik Roshan  2019
# 8                   Good Newwz        Akshay Kumar  2019
# 9            Bhool Bhulaiyaa 2       Kartik Aaryan  2022
# 10       Badrinath Ki Dulhania        Varun Dhawan  2017
# 11    Uri: The Surgical Strike       Vicky Kaushal  2019
